# %% [markdown]
# <a href="https://colab.research.google.com/github/kang-jo/cv_model/blob/main/CNN_TF_DenseNet121.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/datasetV3.zip -d /content/dataset/
# !rm -r /content/dataset
# Out:
# Archive:  /content/datasetV3.zip
#    creating: /content/dataset/Gym Dataset Cropped/
#    creating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_204.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_202.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_200.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_203.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_198.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_194.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_195.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_35.png
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_196.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_197.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_186.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_182.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_190.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_193.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_187.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_189.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_191.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_205.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_185.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_192.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_170.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_173.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_167.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_199.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_169.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_180.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_163.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_184.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_164.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_178.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_166.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_162.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_176.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_179.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_175.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_174.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_177.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_168.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_172.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_171.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_159.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_160.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_158.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_183.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_156.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_188.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_155.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_181.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_161.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_151.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_165.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_157.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_140.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_150.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_153.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_145.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_141.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_138.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_154.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_147.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_142.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_146.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_139.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_148.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_136.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_143.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_144.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_129.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_149.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_134.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_131.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_133.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_130.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_152.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_123.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_137.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_132.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_124.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_119.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_128.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_116.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_126.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_118.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_115.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_127.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_135.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_122.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_201.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_107.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_125.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_111.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_120.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_108.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_104.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_106.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_113.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_109.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_112.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_102.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_121.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_95.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_105.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_100.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_94.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_98.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_103.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_117.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_92.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_97.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_93.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_114.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_85.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_90.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_95.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_101.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_99.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_94.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_91.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_75 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_109.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_93.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_111.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_110.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_96.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_96.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_27 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_102.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/aug_99.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_124.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_11 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_104.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_69.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_14.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_57.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_22.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_143.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_144.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_56 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_139.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_19.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_97.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_105.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_110.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_126.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_108.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_133.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_39.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_66.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_15.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_26 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_38.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_89.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_118.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_67 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_127.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_112.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_122_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_123_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_121.png
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_131.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_70.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_16.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_50.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_11.png
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_106.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_25.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_23.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_120.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_11.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_12.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_116.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_30.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_53.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_34.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_1.png
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_29.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_20.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_21.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_35.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_28.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_46.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_6.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_75.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_134.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_59.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_63.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_3.png
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_55.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_88.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_52.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_67.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_83.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_24.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_44.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_17.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_56.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_81_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_26.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_27.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Lat Pulldown/Image_18.jpg
#    creating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_27.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_73.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_14.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_75.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_77 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_54 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_69.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_76.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_84.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_39.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_51 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_32 (1).png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_56 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_96 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_112.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_13 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_83.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_78.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_34_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_11.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_12_cropped (1).jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_33.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_28.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_104.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_161.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_175.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_183.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_15.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_156.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_164.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_180.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_162.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_153.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_138.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_147.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_172.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_181.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_149.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_134.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_136.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_137.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_131.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_133.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_118.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_178_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_113.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_106.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_122.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_144.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_101.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_100.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_100.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_108.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_88.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_98.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_107.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_126_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_77.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_86.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_64.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_67_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_69_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_71_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_59.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_54.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_81_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_73_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_85.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_22.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_47.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_18.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_12_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_43.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_14.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_13.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_12.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_11.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_4.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_56.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_55.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_33_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_37.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_5.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_143.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_39_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_51.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_132_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_79.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_166.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_169.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_45.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_185.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_171.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_111.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_150.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_29.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_177.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_35.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_155.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_31.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_24.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_116.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_57.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_140.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_44.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_141.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_111.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_114.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_145.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_50.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_139.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_112.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_142.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_159.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_130.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/th13.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_148.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_146.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_49.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_157.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_161.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_32.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_2.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_123.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_135.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/_exercise_bike_nordictrack_commercial_vr21_recumbent_exercise_bike_2000x2000.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Sunny2BHealth2B25262BFitness2BSF2BB4708.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.dq4MJuCT6x-yiFdrAibxvwHaHa2.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Schwinn-230-Recumbent-Bike.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_127.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.8q047mXsZj8k2qbjhCzPJgHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_151.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.bADctsNhnkELJ80LTZfQpAHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/HorizonFitnessRC30RecumbentExerciseBike.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_152.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.g_m8C6lb3tdJkiIX4RwEVwHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.flh9bXo32Ua9oJks0mODRQHaFj.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/real_1312031955471-1.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_121.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.xxb4d9uSj759T9EmuDMqQQHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_154_cropped.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_160.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/908c7923-4767-4bc1-859a-c4628239c1f3_1.62b5d20be01194b8428b9bfbfde72893.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/proform_325_csx_recumbent_exercise_bike_proform_325_csx_recumbent_exercise_bike_2000x2000.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Image_39.png
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Schwinn-270-Recumbent-Exercise-bike-2048x1536.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.f5Rs15KHv2Svmz_30eQRKgHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/image6.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Epic-A17R-Recumbent-Exercise-Bike.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/image8.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.C2ZbX9ZGlRuIjUbe8fMJewHaHf.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Schwinn2B270.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/proform_350_csx_recumbent_exercise_bike_proform_350_csx_recumbent_exercise_bike_2000x2000.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.AmIxzpRHQQ4YsQj5tn2guAHaHa2.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.df2HbLefYcihRNJ7FzatUQHaII.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.09puFKvkvnCxv_E4mW7SLAHaHT2.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Nautilus2BR618.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/recumbent_exercise_bike.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/SchwinnA20.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.5UXT0PRTpj8_hJgHg0xeegHaHu.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.315FPmE5x_4jyvfhSYi2lQHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.iKz5xlpBxu6JlHGXP8FAYAHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.czETF5hiqgqNQntW0I2jpAHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.AmIxzpRHQQ4YsQj5tn2guAHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.L7xCpwp4kGRS3QXXgNmahQHaG0.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/image5.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/JTX-Cyclo-5R-Recumbent-Exercise-Bike.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.utiE_mfaUiCyqeblaYz7SAHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.ix6X44wGWIkzzBRH5iqWsAHaHs2.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.hE-DkO4TQqGV6CaZfdy7_gHaHG.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.w4A5JFvJ9XdQLpeio2apygHaIK.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.dOGuZHUSrFeuZF28cuZ95gHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.OhkMQ96xiHZgRPEVN8Tn3QHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.6HehrNTTJoAApTU_civxfwHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.QSaTrHkJiUTppP40RJFhBwHaIF.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.luMpGK-iyRIh69jyi-sCegHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/6ef66a94-49c8-411b-8366-fb5f130956a4._V304360879_.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.tK5zVZSo61DyRUa7dJXa7wHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/Exerpeutic2BGold2B525xlr.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.09puFKvkvnCxv_E4mW7SLAHaHT.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/real_1601061347451-1917x2000.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.ix6X44wGWIkzzBRH5iqWsAHaHs.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.cBOaA_HxSCbCxmP-TRkg1wHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/39a2a554-6b9c-4da1-968f-a40fe23a52e9_1.ac6e728011a0ba750131603e2ecf8aa0.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.LF_E8uU4wCKjWhHiAG1mnQHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/image2.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.GgVSxZYw55BaaBVeTo2TOwHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/2d1d4171-4e47-400c-be60-44b41b1bbc7f_1.9b2d7eee111bb49709714c5c88651666.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.CRXeh8J2rIK8xxOqVAA8twHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/1ecb8ff2-7d5e-4308-882b-80a8df7fa7a4.90042a72162ea7b831881533d83f3d53.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.JsI6P5ojIIIR_gqjpo2QcQHaFj.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/life-fitness-club-series-plus-recumbent.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/17SCWUSCHWNN270MYBKS.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.pyDCZS6jt9B3kzcJEDghkAHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/recumbent-bike-performance-e50r.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/230-recumbent-bike-my16-brand-new-in.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/image9.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/366630d6-3a7b-4519-bbfd-688071a37e9b_1.c0ce047f088e00127850aee5dbdc6ad6.jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/OIP.1Uim6l2OHqK8y5m0h5jubAHaHa.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Recumbent Bike/recumbent-exercise-bike.jpg
#    creating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_204.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_205.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_202.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_201.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_198.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_133 (1).png
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_195.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_203.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_200.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_190.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_193.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_188.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_199.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_197.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_187.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_192.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_183.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_184.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_182.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_179.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_180.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_185.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_186.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_191.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_171.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_189.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_181.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_165.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_172.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_175.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_161.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_177.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_170.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_168.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_169.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_194.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_178.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_174.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_158.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_196.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_176.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_164.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_160.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_159.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_162.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_149.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_163.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_153.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_150.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_166.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_151.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_141.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_155.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_167.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_156.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_142.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_157.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_146.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_152.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_144.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_148.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_137.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_138.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_136.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_173.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_128.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_131.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_135.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_130.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_127.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_132.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_147.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_145.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_122.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_117.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_139.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_134.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_143.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_124.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_118.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_123.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_140.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_126.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_120.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_125.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_154.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_109.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_108.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_119.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_112.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_129.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_111.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_116.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_107.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_104.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_106.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_133.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_113.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_94.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_114.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_110.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_121.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_90.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_102.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_96.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_99.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_89.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_100.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_91.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_97.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_103.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_98.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_87.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_92.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_88.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_47 (1).png
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_105.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_95.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_90 (1).png
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_86.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_5_cropped (1).jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_9 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_83 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_11_cropped (1).jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_101.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_64 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_93 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_88 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_96_cropped (1).jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_105 (1).png
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_74 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_6 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_93.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_70 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_91 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_42 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_78 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_69 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_99 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_7 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_81 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_22 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_132 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_13 (2).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_77 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_23 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_39 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_27 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_29 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_41 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_25 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_73 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/aug_115.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_3 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_82 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_76 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_26 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_104 (2).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_109 (2).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_85 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_21 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_103 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_18 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_87 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_108 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_17 (2).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_2 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_15 (1).jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_10_cropped (1).jpeg
#   inflating: /content/dataset/Gym Dataset Cropped/Leg Press Machine/Image_1 (1).jpg
# ...
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss138.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss157.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss151.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss169.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss139.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss166.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss121.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss158.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss185.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss175.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss165.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss195.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss149.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss184.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss153.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss197.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss131.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss173.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss187.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss133.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss137.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss188.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss128.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss163.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss168.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss180.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss176.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss191.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss136.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss199.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss181.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss167.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss170.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss90.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss132.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss183.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss146.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss114.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss155.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss122.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss152.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss93.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss119.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss97.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss123.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss196.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss120.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss178.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss124.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss182.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss91.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss96.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss103.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss89.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss110.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss99.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss105.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss108.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss95.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss88.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss87.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss111.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss117.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss104.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss102.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss109.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss66.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss107.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss12.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss113.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss112.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss101.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss32.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss21.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss04.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss60.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss22.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss100.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss20.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss92.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss23.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss39.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss45.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss86.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss16.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss80.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss37.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss03.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss15.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss51.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss08.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss53.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss62.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss98.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss55.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss79.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss18.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss84.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss59.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss78.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss41.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss50.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss48.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss56.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss11.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss70.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss49.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss85.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss05.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss35.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss17.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss42.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss09.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss72.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss10.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss67.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss24.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss26.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss58.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss36.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss33.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss71.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss57.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss07.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss61.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss82.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss28.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss77.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss43.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss01.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss14.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss38.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss52.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss106.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss19.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss64.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss02.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss13.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss73.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss81.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss69.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss75.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss68.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss65.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss63.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss47.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss40.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss54.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss76.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss46.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss31.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss25.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss29.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss44.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss74.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss34.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss06.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss27.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss94.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss83.jpg
#   inflating: /content/dataset/Gym Dataset Cropped/Swiss Ball/imageSwiss30.jpg
#    creating: /content/dataset/tes/
#   inflating: /content/dataset/tes/Decline_Bench_29_jpg.rf.8db7170d393907e116826db4879519d6.jpg
#   inflating: /content/dataset/tes/bench-press-scaled-1248x924.jpg
#   inflating: /content/dataset/tes/Dumbell_7_jpg.rf.976929aa07bceb60695aecd562b73eb3.jpg
#   inflating: /content/dataset/tes/Dumbell_15_jpg.rf.bdbff1ede58d9a9b2d0d01a4632004e7.jpg
#   inflating: /content/dataset/tes/Dumbell_31_jpg.rf.373730d3892871276ad3aff41a170706.jpg
#   inflating: /content/dataset/tes/49620093_de74de6d-b242-4027-a48e-dff29a7bdf26_1280_720.jpg
#   inflating: /content/dataset/tes/em1.jpg
#   inflating: /content/dataset/tes/bp3.jpg
#   inflating: /content/dataset/tes/pullBar_92.jpg
#   inflating: /content/dataset/tes/em.jpeg
#   inflating: /content/dataset/tes/sc.jpeg
#   inflating: /content/dataset/tes/sc1.jpg
#   inflating: /content/dataset/tes/DSC_0125.JPG
#   inflating: /content/dataset/tes/kettlebell-push-ups_1024x.jpg
#   inflating: /content/dataset/tes/bp4.jpg
#   inflating: /content/dataset/tes/Kettlebell-swing.jpg
#   inflating: /content/dataset/tes/sc3.jpg
#   inflating: /content/dataset/tes/bp5.jpg
#   inflating: /content/dataset/tes/VEVOR-Adjustable-Dip-Bar-Station-800-lbs-Capacity-Heavy-Duty-Fitness-Workout-Stand-Stabilizers-Height-Parallel-Bars-Strength-Training-Home-Gym-Equipm_7ea7aa8e-100a-4766-8799-1fcb8084f24a.a9c2f45bb6dc210b4a1348438739d929.webp
#   inflating: /content/dataset/tes/Valor-Fitness-EB-28-Dip-Station-Bars_e3849f2d-f9ce-4b4e-aed1-9884875c9806.e28515c28d5773afcc1a20dab1792877.webp
#   inflating: /content/dataset/tes/us_YJPXSG45YCDLNQ924V0_goods_img-v1_dip-bar-m100-1.12.jpg
#   inflating: /content/dataset/tes/DipBarsWhiteBackground_740x.webp
#   inflating: /content/dataset/tes/41EbJE8li8L._SL1500_.jpg
#   inflating: /content/dataset/tes/x5_1190898559202.jpg
#   inflating: /content/dataset/tes/vevor-kids-toys-yjpxsg12ycdl46dnmv0-64_600.jpg
#   inflating: /content/dataset/tes/maltese_c6061b10-9c25-4e27-be53-938a8f8a7df6.jpg
#   inflating: /content/dataset/tes/aug_88.jpg
#   inflating: /content/dataset/tes/aug_89.jpg
#   inflating: /content/dataset/tes/aug_86.jpg
#   inflating: /content/dataset/tes/aug_87.jpg
#   inflating: /content/dataset/tes/aug_851.jpg
#   inflating: /content/dataset/tes/th15.jpg
#   inflating: /content/dataset/tes/th16.jpg
#   inflating: /content/dataset/tes/th14.jpg
#   inflating: /content/dataset/tes/aug_85.jpg
#   inflating: /content/dataset/tes/aug_84.jpg
#   inflating: /content/dataset/tes/aug_82.jpg
#   inflating: /content/dataset/tes/aug_81.jpg
#   inflating: /content/dataset/tes/aug_83.jpg
#   inflating: /content/dataset/tes/em2.jpg
#   inflating: /content/dataset/tes/pullBar_94.jpg
#   inflating: /content/dataset/tes/pullBar_96.jpg
#   inflating: /content/dataset/tes/Swiss-ball-for-swimmers-FI_185593a4cd.jpg
#   inflating: /content/dataset/tes/Screenshot from 2024-11-26 23-40-59.png
#   inflating: /content/dataset/tes/Screenshot from 2024-11-26 23-41-14.png
#   inflating: /content/dataset/tes/em.jpg

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import regularizers
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.callbacks import EarlyStopping, Callback
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization, Flatten,Input
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import os
import seaborn as sns
sns.set_style('darkgrid')
from sklearn.metrics import confusion_matrix, classification_report
from IPython.display import display, HTML
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ### iterate through the folders to create a dataframe of the form filepaths labels

# %%
sdir=r'./dataset/Gym Dataset Cropped'


filepaths=[]
labels=[]
classlist=os.listdir(sdir)
for klass in classlist:
    classpath=os.path.join(sdir,klass)
    if os.path.isdir(classpath):
        flist=os.listdir(classpath)
        for f in flist:
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(klass)
Fseries= pd.Series(filepaths, name='filepaths')
Lseries=pd.Series(labels, name='labels')
df=pd.concat([Fseries, Lseries], axis=1)
print (df.head())
print (df['labels'].value_counts())
# Out:
#                                            filepaths    labels
# 0  ./dataset/Gym Dataset Cropped/Dumbells/imageDu...  Dumbells
# 1  ./dataset/Gym Dataset Cropped/Dumbells/imageDu...  Dumbells
# 2  ./dataset/Gym Dataset Cropped/Dumbells/imageDu...  Dumbells
# 3  ./dataset/Gym Dataset Cropped/Dumbells/imageDu...  Dumbells
# 4  ./dataset/Gym Dataset Cropped/Dumbells/imageDu...  Dumbells
# labels
# Dumbells              200
# KettleBell            200
# Treadmill             200
# Elliptical Machine    200
# Recumbent Bike        200
# Leg Press Machine     200
# Bench Press           200
# Swiss Ball            200
# Dip Bar               200
# Stair Climber         200
# Lat Pulldown          200
# PullBar               200
# Name: count, dtype: int64

# %% [markdown]
# ### split df into train_df, test_df and valid_df

# %%
train_split = 0.8
test_split = 0.1
dummy_split = test_split / (1 - train_split)

train_df, dummy_df = train_test_split(df, train_size=train_split, stratify=df['labels'], random_state=123)
test_df, valid_df = train_test_split(dummy_df, train_size=dummy_split, stratify=dummy_df['labels'], random_state=123)

print('train_df length:', len(train_df), '  test_df length:', len(test_df), '  valid_df length:', len(valid_df))
# Out:
# train_df length: 1920   test_df length: 240   valid_df length: 240

# %%
print(test_df['labels'].unique())
# Out:
# ['Leg Press Machine' 'Stair Climber' 'Treadmill' 'Dumbells' 'Swiss Ball'
#  'Recumbent Bike' 'Elliptical Machine' 'PullBar' 'KettleBell'
#  'Bench Press' 'Lat Pulldown' 'Dip Bar']

# %% [markdown]
# ### create train, test, valid  generators

# %%
height=224
width=224
channels=3
batch_size=256

img_shape=(height, width, channels)
img_size=(height, width)
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]
test_steps=int(length/test_batch_size)
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps)

gen=ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
    )
train_gen=gen.flow_from_dataframe( train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)

validgen=ImageDataGenerator(rescale=1./255)
valid_gen=validgen.flow_from_dataframe( valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)

testgen=ImageDataGenerator(rescale=1./255)
test_gen=testgen.flow_from_dataframe( test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=False, batch_size=test_batch_size)

classes=list(train_gen.class_indices.keys())
print (classes)
class_count=len(classes)
# Out:
# test batch size:  80   test steps:  3
# Found 1920 validated image filenames belonging to 12 classes.
# Found 240 validated image filenames belonging to 12 classes.
# Found 240 validated image filenames belonging to 12 classes.
# ['Bench Press', 'Dip Bar', 'Dumbells', 'Elliptical Machine', 'KettleBell', 'Lat Pulldown', 'Leg Press Machine', 'PullBar', 'Recumbent Bike', 'Stair Climber', 'Swiss Ball', 'Treadmill']

# %% [markdown]
# ### create function to show some image examples

# %%
def show_image_samples(gen):
    test_dict=test_gen.class_indices
    classes=list(test_dict.keys())
    images,labels=next(gen)
    plt.figure(figsize=(15, 15))
    length=len(labels)
    if length<9:
        r=length
    else:
        r=9
    for i in range(r):
        plt.subplot(3, 3, i + 1)
        image=images[i]
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=16)
        plt.axis('off')
    plt.show()

# %%
labels = train_gen.classes
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels),
    y=labels
)

# %%
class_weights = dict(enumerate(class_weights))
print("Class Weights:", class_weights)
# Out:
# Class Weights: {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0, 4: 1.0, 5: 1.0, 6: 1.0, 7: 1.0, 8: 1.0, 9: 1.0, 10: 1.0, 11: 1.0}

# %%
show_image_samples(train_gen)

# %% [markdown]
# ### create the model

# %%
base_model=tf.keras.applications.DenseNet121(include_top=False, weights="imagenet",input_tensor=Input(shape=(224,224,3)))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
base_model.summary()
# Out:
# Model: "densenet121"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ zero_padding2d            │ (None, 230, 230, 3)    │              0 │ input_layer[0][0]      │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_conv (Conv2D)       │ (None, 112, 112, 64)   │          9,408 │ zero_padding2d[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_bn                  │ (None, 112, 112, 64)   │            256 │ conv1_conv[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_relu (Activation)   │ (None, 112, 112, 64)   │              0 │ conv1_bn[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ zero_padding2d_1          │ (None, 114, 114, 64)   │              0 │ conv1_relu[0][0]       │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool1 (MaxPooling2D)      │ (None, 56, 56, 64)     │              0 │ zero_padding2d_1[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_0_bn         │ (None, 56, 56, 64)     │            256 │ pool1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_0_relu       │ (None, 56, 56, 64)     │              0 │ conv2_block1_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_conv       │ (None, 56, 56, 128)    │          8,192 │ conv2_block1_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_bn         │ (None, 56, 56, 128)    │            512 │ conv2_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_relu       │ (None, 56, 56, 128)    │              0 │ conv2_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_conv       │ (None, 56, 56, 32)     │         36,864 │ conv2_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_concat       │ (None, 56, 56, 96)     │              0 │ pool1[0][0],           │
# │ (Concatenate)             │                        │                │ conv2_block1_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_0_bn         │ (None, 56, 56, 96)     │            384 │ conv2_block1_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_0_relu       │ (None, 56, 56, 96)     │              0 │ conv2_block2_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_conv       │ (None, 56, 56, 128)    │         12,288 │ conv2_block2_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_bn         │ (None, 56, 56, 128)    │            512 │ conv2_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_relu       │ (None, 56, 56, 128)    │              0 │ conv2_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_2_conv       │ (None, 56, 56, 32)     │         36,864 │ conv2_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_concat       │ (None, 56, 56, 128)    │              0 │ conv2_block1_concat[0… │
# │ (Concatenate)             │                        │                │ conv2_block2_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_0_bn         │ (None, 56, 56, 128)    │            512 │ conv2_block2_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_0_relu       │ (None, 56, 56, 128)    │              0 │ conv2_block3_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_conv       │ (None, 56, 56, 128)    │         16,384 │ conv2_block3_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_bn         │ (None, 56, 56, 128)    │            512 │ conv2_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_relu       │ (None, 56, 56, 128)    │              0 │ conv2_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_2_conv       │ (None, 56, 56, 32)     │         36,864 │ conv2_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_concat       │ (None, 56, 56, 160)    │              0 │ conv2_block2_concat[0… │
# │ (Concatenate)             │                        │                │ conv2_block3_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_0_bn         │ (None, 56, 56, 160)    │            640 │ conv2_block3_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_0_relu       │ (None, 56, 56, 160)    │              0 │ conv2_block4_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_1_conv       │ (None, 56, 56, 128)    │         20,480 │ conv2_block4_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_1_bn         │ (None, 56, 56, 128)    │            512 │ conv2_block4_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_1_relu       │ (None, 56, 56, 128)    │              0 │ conv2_block4_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_2_conv       │ (None, 56, 56, 32)     │         36,864 │ conv2_block4_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_concat       │ (None, 56, 56, 192)    │              0 │ conv2_block3_concat[0… │
# │ (Concatenate)             │                        │                │ conv2_block4_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_0_bn         │ (None, 56, 56, 192)    │            768 │ conv2_block4_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_0_relu       │ (None, 56, 56, 192)    │              0 │ conv2_block5_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_1_conv       │ (None, 56, 56, 128)    │         24,576 │ conv2_block5_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_1_bn         │ (None, 56, 56, 128)    │            512 │ conv2_block5_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_1_relu       │ (None, 56, 56, 128)    │              0 │ conv2_block5_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_2_conv       │ (None, 56, 56, 32)     │         36,864 │ conv2_block5_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_concat       │ (None, 56, 56, 224)    │              0 │ conv2_block4_concat[0… │
# │ (Concatenate)             │                        │                │ conv2_block5_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_0_bn         │ (None, 56, 56, 224)    │            896 │ conv2_block5_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_0_relu       │ (None, 56, 56, 224)    │              0 │ conv2_block6_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_1_conv       │ (None, 56, 56, 128)    │         28,672 │ conv2_block6_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_1_bn         │ (None, 56, 56, 128)    │            512 │ conv2_block6_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_1_relu       │ (None, 56, 56, 128)    │              0 │ conv2_block6_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_2_conv       │ (None, 56, 56, 32)     │         36,864 │ conv2_block6_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_concat       │ (None, 56, 56, 256)    │              0 │ conv2_block5_concat[0… │
# │ (Concatenate)             │                        │                │ conv2_block6_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool2_bn                  │ (None, 56, 56, 256)    │          1,024 │ conv2_block6_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool2_relu (Activation)   │ (None, 56, 56, 256)    │              0 │ pool2_bn[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool2_conv (Conv2D)       │ (None, 56, 56, 128)    │         32,768 │ pool2_relu[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool2_pool                │ (None, 28, 28, 128)    │              0 │ pool2_conv[0][0]       │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_0_bn         │ (None, 28, 28, 128)    │            512 │ pool2_pool[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_0_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block1_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_conv       │ (None, 28, 28, 128)    │         16,384 │ conv3_block1_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_concat       │ (None, 28, 28, 160)    │              0 │ pool2_pool[0][0],      │
# │ (Concatenate)             │                        │                │ conv3_block1_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_0_bn         │ (None, 28, 28, 160)    │            640 │ conv3_block1_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_0_relu       │ (None, 28, 28, 160)    │              0 │ conv3_block2_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_conv       │ (None, 28, 28, 128)    │         20,480 │ conv3_block2_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_concat       │ (None, 28, 28, 192)    │              0 │ conv3_block1_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block2_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_0_bn         │ (None, 28, 28, 192)    │            768 │ conv3_block2_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_0_relu       │ (None, 28, 28, 192)    │              0 │ conv3_block3_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_conv       │ (None, 28, 28, 128)    │         24,576 │ conv3_block3_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_concat       │ (None, 28, 28, 224)    │              0 │ conv3_block2_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block3_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_0_bn         │ (None, 28, 28, 224)    │            896 │ conv3_block3_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_0_relu       │ (None, 28, 28, 224)    │              0 │ conv3_block4_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_conv       │ (None, 28, 28, 128)    │         28,672 │ conv3_block4_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block4_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block4_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block4_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_concat       │ (None, 28, 28, 256)    │              0 │ conv3_block3_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block4_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_0_bn         │ (None, 28, 28, 256)    │          1,024 │ conv3_block4_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_0_relu       │ (None, 28, 28, 256)    │              0 │ conv3_block5_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_1_conv       │ (None, 28, 28, 128)    │         32,768 │ conv3_block5_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block5_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block5_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block5_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_concat       │ (None, 28, 28, 288)    │              0 │ conv3_block4_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block5_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_0_bn         │ (None, 28, 28, 288)    │          1,152 │ conv3_block5_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_0_relu       │ (None, 28, 28, 288)    │              0 │ conv3_block6_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_1_conv       │ (None, 28, 28, 128)    │         36,864 │ conv3_block6_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block6_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block6_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block6_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_concat       │ (None, 28, 28, 320)    │              0 │ conv3_block5_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block6_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_0_bn         │ (None, 28, 28, 320)    │          1,280 │ conv3_block6_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_0_relu       │ (None, 28, 28, 320)    │              0 │ conv3_block7_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_1_conv       │ (None, 28, 28, 128)    │         40,960 │ conv3_block7_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block7_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block7_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block7_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_concat       │ (None, 28, 28, 352)    │              0 │ conv3_block6_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block7_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block8_0_bn         │ (None, 28, 28, 352)    │          1,408 │ conv3_block7_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block8_0_relu       │ (None, 28, 28, 352)    │              0 │ conv3_block8_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block8_1_conv       │ (None, 28, 28, 128)    │         45,056 │ conv3_block8_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block8_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block8_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block8_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block8_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block8_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block8_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block8_concat       │ (None, 28, 28, 384)    │              0 │ conv3_block7_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block8_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block9_0_bn         │ (None, 28, 28, 384)    │          1,536 │ conv3_block8_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block9_0_relu       │ (None, 28, 28, 384)    │              0 │ conv3_block9_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block9_1_conv       │ (None, 28, 28, 128)    │         49,152 │ conv3_block9_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block9_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block9_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block9_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block9_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block9_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block9_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block9_concat       │ (None, 28, 28, 416)    │              0 │ conv3_block8_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block9_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block10_0_bn        │ (None, 28, 28, 416)    │          1,664 │ conv3_block9_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block10_0_relu      │ (None, 28, 28, 416)    │              0 │ conv3_block10_0_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block10_1_conv      │ (None, 28, 28, 128)    │         53,248 │ conv3_block10_0_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block10_1_bn        │ (None, 28, 28, 128)    │            512 │ conv3_block10_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block10_1_relu      │ (None, 28, 28, 128)    │              0 │ conv3_block10_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block10_2_conv      │ (None, 28, 28, 32)     │         36,864 │ conv3_block10_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block10_concat      │ (None, 28, 28, 448)    │              0 │ conv3_block9_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block10_2_conv[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block11_0_bn        │ (None, 28, 28, 448)    │          1,792 │ conv3_block10_concat[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block11_0_relu      │ (None, 28, 28, 448)    │              0 │ conv3_block11_0_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block11_1_conv      │ (None, 28, 28, 128)    │         57,344 │ conv3_block11_0_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block11_1_bn        │ (None, 28, 28, 128)    │            512 │ conv3_block11_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block11_1_relu      │ (None, 28, 28, 128)    │              0 │ conv3_block11_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block11_2_conv      │ (None, 28, 28, 32)     │         36,864 │ conv3_block11_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block11_concat      │ (None, 28, 28, 480)    │              0 │ conv3_block10_concat[… │
# │ (Concatenate)             │                        │                │ conv3_block11_2_conv[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block12_0_bn        │ (None, 28, 28, 480)    │          1,920 │ conv3_block11_concat[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block12_0_relu      │ (None, 28, 28, 480)    │              0 │ conv3_block12_0_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block12_1_conv      │ (None, 28, 28, 128)    │         61,440 │ conv3_block12_0_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block12_1_bn        │ (None, 28, 28, 128)    │            512 │ conv3_block12_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block12_1_relu      │ (None, 28, 28, 128)    │              0 │ conv3_block12_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block12_2_conv      │ (None, 28, 28, 32)     │         36,864 │ conv3_block12_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block12_concat      │ (None, 28, 28, 512)    │              0 │ conv3_block11_concat[… │
# │ (Concatenate)             │                        │                │ conv3_block12_2_conv[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool3_bn                  │ (None, 28, 28, 512)    │          2,048 │ conv3_block12_concat[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool3_relu (Activation)   │ (None, 28, 28, 512)    │              0 │ pool3_bn[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool3_conv (Conv2D)       │ (None, 28, 28, 256)    │        131,072 │ pool3_relu[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool3_pool                │ (None, 14, 14, 256)    │              0 │ pool3_conv[0][0]       │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_0_bn         │ (None, 14, 14, 256)    │          1,024 │ pool3_pool[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_0_relu       │ (None, 14, 14, 256)    │              0 │ conv4_block1_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_1_conv       │ (None, 14, 14, 128)    │         32,768 │ conv4_block1_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_1_bn         │ (None, 14, 14, 128)    │            512 │ conv4_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_1_relu       │ (None, 14, 14, 128)    │              0 │ conv4_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_2_conv       │ (None, 14, 14, 32)     │         36,864 │ conv4_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_concat       │ (None, 14, 14, 288)    │              0 │ pool3_pool[0][0],      │
# │ (Concatenate)             │                        │                │ conv4_block1_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_0_bn         │ (None, 14, 14, 288)    │          1,152 │ conv4_block1_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_0_relu       │ (None, 14, 14, 288)    │              0 │ conv4_block2_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_1_conv       │ (None, 14, 14, 128)    │         36,864 │ conv4_block2_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_1_bn         │ (None, 14, 14, 128)    │            512 │ conv4_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_1_relu       │ (None, 14, 14, 128)    │              0 │ conv4_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_2_conv       │ (None, 14, 14, 32)     │         36,864 │ conv4_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_concat       │ (None, 14, 14, 320)    │              0 │ conv4_block1_concat[0… │
# │ (Concatenate)             │                        │                │ conv4_block2_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_0_bn         │ (None, 14, 14, 320)    │          1,280 │ conv4_block2_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_0_relu       │ (None, 14, 14, 320)    │              0 │ conv4_block3_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_1_conv       │ (None, 14, 14, 128)    │         40,960 │ conv4_block3_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_1_bn         │ (None, 14, 14, 128)    │            512 │ conv4_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_1_relu       │ (None, 14, 14, 128)    │              0 │ conv4_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_2_conv       │ (None, 14, 14, 32)     │         36,864 │ conv4_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_concat       │ (None, 14, 14, 352)    │              0 │ conv4_block2_concat[0… │
# │ (Concatenate)             │                        │                │ conv4_block3_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_0_bn         │ (None, 14, 14, 352)    │          1,408 │ conv4_block3_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_0_relu       │ (None, 14, 14, 352)    │              0 │ conv4_block4_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_1_conv       │ (None, 14, 14, 128)    │         45,056 │ conv4_block4_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_1_bn         │ (None, 14, 14, 128)    │            512 │ conv4_block4_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_1_relu       │ (None, 14, 14, 128)    │              0 │ conv4_block4_1_bn[0][… │
# ...
# │ conv5_block9_1_bn         │ (None, 7, 7, 128)      │            512 │ conv5_block9_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block9_1_relu       │ (None, 7, 7, 128)      │              0 │ conv5_block9_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block9_2_conv       │ (None, 7, 7, 32)       │         36,864 │ conv5_block9_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block9_concat       │ (None, 7, 7, 800)      │              0 │ conv5_block8_concat[0… │
# │ (Concatenate)             │                        │                │ conv5_block9_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block10_0_bn        │ (None, 7, 7, 800)      │          3,200 │ conv5_block9_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block10_0_relu      │ (None, 7, 7, 800)      │              0 │ conv5_block10_0_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block10_1_conv      │ (None, 7, 7, 128)      │        102,400 │ conv5_block10_0_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block10_1_bn        │ (None, 7, 7, 128)      │            512 │ conv5_block10_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block10_1_relu      │ (None, 7, 7, 128)      │              0 │ conv5_block10_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block10_2_conv      │ (None, 7, 7, 32)       │         36,864 │ conv5_block10_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block10_concat      │ (None, 7, 7, 832)      │              0 │ conv5_block9_concat[0… │
# │ (Concatenate)             │                        │                │ conv5_block10_2_conv[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block11_0_bn        │ (None, 7, 7, 832)      │          3,328 │ conv5_block10_concat[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block11_0_relu      │ (None, 7, 7, 832)      │              0 │ conv5_block11_0_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block11_1_conv      │ (None, 7, 7, 128)      │        106,496 │ conv5_block11_0_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block11_1_bn        │ (None, 7, 7, 128)      │            512 │ conv5_block11_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block11_1_relu      │ (None, 7, 7, 128)      │              0 │ conv5_block11_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block11_2_conv      │ (None, 7, 7, 32)       │         36,864 │ conv5_block11_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block11_concat      │ (None, 7, 7, 864)      │              0 │ conv5_block10_concat[… │
# │ (Concatenate)             │                        │                │ conv5_block11_2_conv[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block12_0_bn        │ (None, 7, 7, 864)      │          3,456 │ conv5_block11_concat[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block12_0_relu      │ (None, 7, 7, 864)      │              0 │ conv5_block12_0_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block12_1_conv      │ (None, 7, 7, 128)      │        110,592 │ conv5_block12_0_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block12_1_bn        │ (None, 7, 7, 128)      │            512 │ conv5_block12_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block12_1_relu      │ (None, 7, 7, 128)      │              0 │ conv5_block12_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block12_2_conv      │ (None, 7, 7, 32)       │         36,864 │ conv5_block12_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block12_concat      │ (None, 7, 7, 896)      │              0 │ conv5_block11_concat[… │
# │ (Concatenate)             │                        │                │ conv5_block12_2_conv[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block13_0_bn        │ (None, 7, 7, 896)      │          3,584 │ conv5_block12_concat[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block13_0_relu      │ (None, 7, 7, 896)      │              0 │ conv5_block13_0_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block13_1_conv      │ (None, 7, 7, 128)      │        114,688 │ conv5_block13_0_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block13_1_bn        │ (None, 7, 7, 128)      │            512 │ conv5_block13_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block13_1_relu      │ (None, 7, 7, 128)      │              0 │ conv5_block13_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block13_2_conv      │ (None, 7, 7, 32)       │         36,864 │ conv5_block13_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block13_concat      │ (None, 7, 7, 928)      │              0 │ conv5_block12_concat[… │
# │ (Concatenate)             │                        │                │ conv5_block13_2_conv[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block14_0_bn        │ (None, 7, 7, 928)      │          3,712 │ conv5_block13_concat[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block14_0_relu      │ (None, 7, 7, 928)      │              0 │ conv5_block14_0_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block14_1_conv      │ (None, 7, 7, 128)      │        118,784 │ conv5_block14_0_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block14_1_bn        │ (None, 7, 7, 128)      │            512 │ conv5_block14_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block14_1_relu      │ (None, 7, 7, 128)      │              0 │ conv5_block14_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block14_2_conv      │ (None, 7, 7, 32)       │         36,864 │ conv5_block14_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block14_concat      │ (None, 7, 7, 960)      │              0 │ conv5_block13_concat[… │
# │ (Concatenate)             │                        │                │ conv5_block14_2_conv[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block15_0_bn        │ (None, 7, 7, 960)      │          3,840 │ conv5_block14_concat[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block15_0_relu      │ (None, 7, 7, 960)      │              0 │ conv5_block15_0_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block15_1_conv      │ (None, 7, 7, 128)      │        122,880 │ conv5_block15_0_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block15_1_bn        │ (None, 7, 7, 128)      │            512 │ conv5_block15_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block15_1_relu      │ (None, 7, 7, 128)      │              0 │ conv5_block15_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block15_2_conv      │ (None, 7, 7, 32)       │         36,864 │ conv5_block15_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block15_concat      │ (None, 7, 7, 992)      │              0 │ conv5_block14_concat[… │
# │ (Concatenate)             │                        │                │ conv5_block15_2_conv[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block16_0_bn        │ (None, 7, 7, 992)      │          3,968 │ conv5_block15_concat[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block16_0_relu      │ (None, 7, 7, 992)      │              0 │ conv5_block16_0_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block16_1_conv      │ (None, 7, 7, 128)      │        126,976 │ conv5_block16_0_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block16_1_bn        │ (None, 7, 7, 128)      │            512 │ conv5_block16_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block16_1_relu      │ (None, 7, 7, 128)      │              0 │ conv5_block16_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block16_2_conv      │ (None, 7, 7, 32)       │         36,864 │ conv5_block16_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block16_concat      │ (None, 7, 7, 1024)     │              0 │ conv5_block15_concat[… │
# │ (Concatenate)             │                        │                │ conv5_block16_2_conv[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn (BatchNormalization)   │ (None, 7, 7, 1024)     │          4,096 │ conv5_block16_concat[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ relu (Activation)         │ (None, 7, 7, 1024)     │              0 │ bn[0][0]               │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,037,504 (26.85 MB)
#  Trainable params: 6,953,856 (26.53 MB)
#  Non-trainable params: 83,648 (326.75 KB)

# %%
base_model.trainable = False
# for layer in base_model.layers[:100]:  # Freeze lapisan awal
#     layer.trainable = False
# for layer in base_model.layers[-20:]:  # Unfreeze lapisan terakhir
#     layer.trainable = True

# %%
# new_base = ResNet50(include_top=False, weights='imagenet', input_shape=(224, 224, 3))

# %%
# new_base.summary()

# %%
model_name='GymLens'
print("Building model with", base_model)
model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.Conv2D(filters=64, padding='same', kernel_size=3, activation='relu', strides=1),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(filters=64, padding='same', kernel_size=3, activation='relu', strides=1),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(filters=128, padding='same', kernel_size=3, activation='relu', strides=1),
    tf.keras.layers.MaxPool2D(pool_size=(1, 1)),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4)),
    tf.keras.layers.Dense(class_count, activation='softmax')
])


model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=.0001), loss='categorical_crossentropy', metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
# Out:
# Building model with <Functional name=densenet121, built=True>

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ densenet121 (Functional)             │ (None, 7, 7, 1024)          │       7,037,504 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 7, 7, 64)            │         589,888 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 3, 3, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 3, 3, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 1, 1, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 1, 1, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 1, 1, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1, 1, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 1, 1, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │          66,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 12)                  │           6,156 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,810,892 (29.80 MB)
#  Trainable params: 773,132 (2.95 MB)
#  Non-trainable params: 7,037,760 (26.85 MB)

# %%
class EarlyStoppingAtAccuracy(Callback):
    def __init__(self, target_accuracy):
        super().__init__()
        self.target_accuracy = target_accuracy

    def on_epoch_end(self, epoch, logs=None):
        val_acc = logs.get('val_accuracy')
        if val_acc and val_acc >= self.target_accuracy:
            print(f"\nStopping training as validation accuracy reached {val_acc:.2f} (≥ {self.target_accuracy:.2f})")
            self.model.stop_training = True

early_stopping = EarlyStoppingAtAccuracy(target_accuracy=0.98)

# %%
callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=7,
        verbose=1,
        restore_best_weights=True
    )
]

# %%
epochs = 100

history=model.fit(
    x=train_gen,
    batch_size=32,
    epochs=epochs,
    validation_data=valid_gen,
    # class_weight=class_weights,
    callbacks=[callbacks]
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 162s 14s/step - accuracy: 0.1352 - loss: 2.5978 - precision: 0.1481 - recall: 2.6143e-04 - val_accuracy: 0.2208 - val_loss: 2.4630 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 84s 744ms/step - accuracy: 0.1816 - loss: 2.3979 - precision: 0.8889 - recall: 0.0016 - val_accuracy: 0.3375 - val_loss: 2.3909 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 721ms/step - accuracy: 0.2729 - loss: 2.2007 - precision: 1.0000 - recall: 0.0108 - val_accuracy: 0.4708 - val_loss: 2.3083 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 712ms/step - accuracy: 0.3440 - loss: 2.0467 - precision: 1.0000 - recall: 0.0333 - val_accuracy: 0.5750 - val_loss: 2.2022 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 761ms/step - accuracy: 0.4726 - loss: 1.8217 - precision: 0.9880 - recall: 0.0873 - val_accuracy: 0.6500 - val_loss: 2.0841 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 721ms/step - accuracy: 0.5241 - loss: 1.7058 - precision: 0.9608 - recall: 0.1130 - val_accuracy: 0.7042 - val_loss: 1.9647 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 895ms/step - accuracy: 0.5897 - loss: 1.5650 - precision: 0.9818 - recall: 0.1407 - val_accuracy: 0.7542 - val_loss: 1.8453 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 711ms/step - accuracy: 0.6489 - loss: 1.4264 - precision: 0.9831 - recall: 0.1815 - val_accuracy: 0.8000 - val_loss: 1.7240 - val_precision: 1.0000 - val_recall: 0.0042 - learning_rate: 1.0000e-04
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 719ms/step - accuracy: 0.6901 - loss: 1.3125 - precision: 0.9451 - recall: 0.2249 - val_accuracy: 0.8417 - val_loss: 1.6060 - val_precision: 1.0000 - val_recall: 0.0250 - learning_rate: 1.0000e-04
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 763ms/step - accuracy: 0.7378 - loss: 1.1935 - precision: 0.9839 - recall: 0.2749 - val_accuracy: 0.8625 - val_loss: 1.4829 - val_precision: 1.0000 - val_recall: 0.0583 - learning_rate: 1.0000e-04
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 720ms/step - accuracy: 0.7673 - loss: 1.0915 - precision: 0.9687 - recall: 0.3230 - val_accuracy: 0.8833 - val_loss: 1.3545 - val_precision: 1.0000 - val_recall: 0.1042 - learning_rate: 1.0000e-04
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 713ms/step - accuracy: 0.8221 - loss: 0.9751 - precision: 0.9599 - recall: 0.3960 - val_accuracy: 0.8875 - val_loss: 1.2159 - val_precision: 1.0000 - val_recall: 0.1792 - learning_rate: 1.0000e-04
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 739ms/step - accuracy: 0.8321 - loss: 0.8850 - precision: 0.9630 - recall: 0.4836 - val_accuracy: 0.9167 - val_loss: 1.0919 - val_precision: 1.0000 - val_recall: 0.2833 - learning_rate: 1.0000e-04
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 714ms/step - accuracy: 0.8553 - loss: 0.7922 - precision: 0.9722 - recall: 0.5327 - val_accuracy: 0.9333 - val_loss: 0.9848 - val_precision: 1.0000 - val_recall: 0.3375 - learning_rate: 1.0000e-04
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 769ms/step - accuracy: 0.8827 - loss: 0.7073 - precision: 0.9824 - recall: 0.5976 - val_accuracy: 0.9458 - val_loss: 0.8802 - val_precision: 0.9894 - val_recall: 0.3875 - learning_rate: 1.0000e-04
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 717ms/step - accuracy: 0.8984 - loss: 0.6456 - precision: 0.9749 - recall: 0.6494 - val_accuracy: 0.9625 - val_loss: 0.7779 - val_precision: 0.9919 - val_recall: 0.5083 - learning_rate: 1.0000e-04
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 724ms/step - accuracy: 0.8924 - loss: 0.6056 - precision: 0.9696 - recall: 0.6811 - val_accuracy: 0.9667 - val_loss: 0.6892 - val_precision: 0.9933 - val_recall: 0.6167 - learning_rate: 1.0000e-04
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 728ms/step - accuracy: 0.9234 - loss: 0.5397 - precision: 0.9814 - recall: 0.7241 - val_accuracy: 0.9750 - val_loss: 0.6058 - val_precision: 0.9938 - val_recall: 0.6708 - learning_rate: 1.0000e-04
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 725ms/step - accuracy: 0.9257 - loss: 0.4894 - precision: 0.9829 - recall: 0.7694 - val_accuracy: 0.9792 - val_loss: 0.5243 - val_precision: 0.9943 - val_recall: 0.7292 - learning_rate: 1.0000e-04
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 719ms/step - accuracy: 0.9292 - loss: 0.4542 - precision: 0.9837 - recall: 0.8027 - val_accuracy: 0.9792 - val_loss: 0.4541 - val_precision: 1.0000 - val_recall: 0.7875 - learning_rate: 1.0000e-04
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 735ms/step - accuracy: 0.9474 - loss: 0.4204 - precision: 0.9840 - recall: 0.8122 - val_accuracy: 0.9875 - val_loss: 0.4061 - val_precision: 1.0000 - val_recall: 0.8167 - learning_rate: 1.0000e-04
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 719ms/step - accuracy: 0.9378 - loss: 0.3919 - precision: 0.9830 - recall: 0.8316 - val_accuracy: 0.9875 - val_loss: 0.3504 - val_precision: 0.9952 - val_recall: 0.8583 - learning_rate: 1.0000e-04
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 766ms/step - accuracy: 0.9556 - loss: 0.3496 - precision: 0.9869 - recall: 0.8568 - val_accuracy: 0.9917 - val_loss: 0.3120 - val_precision: 0.9953 - val_recall: 0.8917 - learning_rate: 1.0000e-04
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 30s 732ms/step - accuracy: 0.9381 - loss: 0.3545 - precision: 0.9826 - recall: 0.8565 - val_accuracy: 0.9917 - val_loss: 0.2892 - val_precision: 1.0000 - val_recall: 0.9083 - learning_rate: 1.0000e-04
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 729ms/step - accuracy: 0.9546 - loss: 0.3250 - precision: 0.9840 - recall: 0.8771 - val_accuracy: 0.9917 - val_loss: 0.2553 - val_precision: 0.9955 - val_recall: 0.9292 - learning_rate: 1.0000e-04
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 718ms/step - accuracy: 0.9598 - loss: 0.2808 - precision: 0.9867 - recall: 0.9052 - val_accuracy: 0.9917 - val_loss: 0.2290 - val_precision: 0.9956 - val_recall: 0.9417 - learning_rate: 1.0000e-04
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 733ms/step - accuracy: 0.9565 - loss: 0.2813 - precision: 0.9859 - recall: 0.9017 - val_accuracy: 0.9917 - val_loss: 0.2098 - val_precision: 0.9913 - val_recall: 0.9458 - learning_rate: 1.0000e-04
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 904ms/step - accuracy: 0.9650 - loss: 0.2503 - precision: 0.9865 - recall: 0.9174 - val_accuracy: 0.9917 - val_loss: 0.1895 - val_precision: 0.9915 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 736ms/step - accuracy: 0.9557 - loss: 0.2600 - precision: 0.9779 - recall: 0.9139 - val_accuracy: 0.9917 - val_loss: 0.1751 - val_precision: 0.9915 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 911ms/step - accuracy: 0.9536 - loss: 0.2496 - precision: 0.9836 - recall: 0.9083 - val_accuracy: 0.9875 - val_loss: 0.1545 - val_precision: 0.9873 - val_recall: 0.9708 - learning_rate: 1.0000e-04
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 748ms/step - accuracy: 0.9661 - loss: 0.2275 - precision: 0.9920 - recall: 0.9260 - val_accuracy: 0.9917 - val_loss: 0.1485 - val_precision: 0.9957 - val_recall: 0.9708 - learning_rate: 1.0000e-04
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 754ms/step - accuracy: 0.9749 - loss: 0.2112 - precision: 0.9892 - recall: 0.9344 - val_accuracy: 0.9917 - val_loss: 0.1466 - val_precision: 0.9915 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 770ms/step - accuracy: 0.9698 - loss: 0.2160 - precision: 0.9859 - recall: 0.9301 - val_accuracy: 0.9875 - val_loss: 0.1369 - val_precision: 0.9957 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 771ms/step - accuracy: 0.9671 - loss: 0.1983 - precision: 0.9831 - recall: 0.9378 - val_accuracy: 0.9875 - val_loss: 0.1185 - val_precision: 0.9874 - val_recall: 0.9833 - learning_rate: 1.0000e-04
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 823ms/step - accuracy: 0.9751 - loss: 0.2007 - precision: 0.9886 - recall: 0.9382 - val_accuracy: 0.9875 - val_loss: 0.1107 - val_precision: 0.9874 - val_recall: 0.9833 - learning_rate: 1.0000e-04
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 751ms/step - accuracy: 0.9687 - loss: 0.2060 - precision: 0.9833 - recall: 0.9350 - val_accuracy: 0.9917 - val_loss: 0.1206 - val_precision: 0.9916 - val_recall: 0.9833 - learning_rate: 1.0000e-04
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 815ms/step - accuracy: 0.9668 - loss: 0.1821 - precision: 0.9844 - recall: 0.9364 - val_accuracy: 0.9917 - val_loss: 0.0988 - val_precision: 0.9916 - val_recall: 0.9875 - learning_rate: 1.0000e-04
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 918ms/step - accuracy: 0.9755 - loss: 0.1727 - precision: 0.9866 - recall: 0.9514 - val_accuracy: 0.9917 - val_loss: 0.1015 - val_precision: 0.9916 - val_recall: 0.9792 - learning_rate: 1.0000e-04
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 736ms/step - accuracy: 0.9759 - loss: 0.1698 - precision: 0.9864 - recall: 0.9514 - val_accuracy: 0.9875 - val_loss: 0.1018 - val_precision: 0.9874 - val_recall: 0.9792 - learning_rate: 1.0000e-04
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 776ms/step - accuracy: 0.9805 - loss: 0.1539 - precision: 0.9884 - recall: 0.9618 - val_accuracy: 0.9958 - val_loss: 0.0981 - val_precision: 0.9958 - val_recall: 0.9792 - learning_rate: 1.0000e-04
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 767ms/step - accuracy: 0.9795 - loss: 0.1489 - precision: 0.9889 - recall: 0.9630 - val_accuracy: 0.9875 - val_loss: 0.0836 - val_precision: 0.9875 - val_recall: 0.9875 - learning_rate: 1.0000e-04
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 33s 948ms/step - accuracy: 0.9845 - loss: 0.1435 - precision: 0.9922 - recall: 0.9637 - val_accuracy: 0.9917 - val_loss: 0.0771 - val_precision: 0.9917 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 758ms/step - accuracy: 0.9802 - loss: 0.1448 - precision: 0.9833 - recall: 0.9631 - val_accuracy: 0.9958 - val_loss: 0.0768 - val_precision: 0.9958 - val_recall: 0.9958 - learning_rate: 1.0000e-04
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 847ms/step - accuracy: 0.9863 - loss: 0.1335 - precision: 0.9945 - recall: 0.9693 - val_accuracy: 0.9875 - val_loss: 0.0775 - val_precision: 0.9916 - val_recall: 0.9875 - learning_rate: 1.0000e-04
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 770ms/step - accuracy: 0.9850 - loss: 0.1217 - precision: 0.9904 - recall: 0.9760 - val_accuracy: 0.9917 - val_loss: 0.0732 - val_precision: 0.9916 - val_recall: 0.9875 - learning_rate: 1.0000e-04
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 773ms/step - accuracy: 0.9799 - loss: 0.1299 - precision: 0.9901 - recall: 0.9665 - val_accuracy: 0.9917 - val_loss: 0.0677 - val_precision: 0.9917 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 779ms/step - accuracy: 0.9825 - loss: 0.1254 - precision: 0.9876 - recall: 0.9684 - val_accuracy: 0.9958 - val_loss: 0.0665 - val_precision: 0.9958 - val_recall: 0.9958 - learning_rate: 1.0000e-04
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 779ms/step - accuracy: 0.9821 - loss: 0.1265 - precision: 0.9858 - recall: 0.9624 - val_accuracy: 0.9875 - val_loss: 0.0686 - val_precision: 0.9875 - val_recall: 0.9875 - learning_rate: 1.0000e-04
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 781ms/step - accuracy: 0.9866 - loss: 0.1121 - precision: 0.9939 - recall: 0.9707 - val_accuracy: 0.9917 - val_loss: 0.0655 - val_precision: 0.9916 - val_recall: 0.9875 - learning_rate: 1.0000e-04
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 774ms/step - accuracy: 0.9819 - loss: 0.1252 - precision: 0.9895 - recall: 0.9684 - val_accuracy: 0.9958 - val_loss: 0.0569 - val_precision: 0.9958 - val_recall: 0.9958 - learning_rate: 1.0000e-04
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 33s 920ms/step - accuracy: 0.9874 - loss: 0.1005 - precision: 0.9952 - recall: 0.9784 - val_accuracy: 0.9875 - val_loss: 0.0634 - val_precision: 0.9874 - val_recall: 0.9833 - learning_rate: 1.0000e-04
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 834ms/step - accuracy: 0.9847 - loss: 0.1125 - precision: 0.9886 - recall: 0.9734 - val_accuracy: 0.9917 - val_loss: 0.0642 - val_precision: 0.9917 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 763ms/step - accuracy: 0.9911 - loss: 0.1009 - precision: 0.9933 - recall: 0.9800 - val_accuracy: 0.9958 - val_loss: 0.0553 - val_precision: 0.9958 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 775ms/step - accuracy: 0.9851 - loss: 0.1060 - precision: 0.9911 - recall: 0.9769 - val_accuracy: 0.9917 - val_loss: 0.0754 - val_precision: 0.9916 - val_recall: 0.9875 - learning_rate: 1.0000e-04
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 757ms/step - accuracy: 0.9830 - loss: 0.1061 - precision: 0.9889 - recall: 0.9732 - val_accuracy: 0.9917 - val_loss: 0.0567 - val_precision: 0.9917 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 772ms/step - accuracy: 0.9878 - loss: 0.1077 - precision: 0.9906 - recall: 0.9767 - val_accuracy: 0.9958 - val_loss: 0.0525 - val_precision: 0.9958 - val_recall: 0.9958 - learning_rate: 1.0000e-04
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 790ms/step - accuracy: 0.9865 - loss: 0.0978 - precision: 0.9910 - recall: 0.9821 - val_accuracy: 0.9958 - val_loss: 0.0550 - val_precision: 0.9958 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 739ms/step - accuracy: 0.9874 - loss: 0.0936 - precision: 0.9890 - recall: 0.9819 - val_accuracy: 0.9875 - val_loss: 0.0630 - val_precision: 0.9875 - val_recall: 0.9875 - learning_rate: 1.0000e-04
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 812ms/step - accuracy: 0.9878 - loss: 0.0925 - precision: 0.9912 - recall: 0.9778 - val_accuracy: 0.9917 - val_loss: 0.0494 - val_precision: 0.9958 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 31s 742ms/step - accuracy: 0.9868 - loss: 0.0938 - precision: 0.9938 - recall: 0.9818 - val_accuracy: 0.9958 - val_loss: 0.0501 - val_precision: 0.9958 - val_recall: 0.9958 - learning_rate: 1.0000e-04
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 783ms/step - accuracy: 0.9900 - loss: 0.0884 - precision: 0.9943 - recall: 0.9791 - val_accuracy: 0.9917 - val_loss: 0.0627 - val_precision: 0.9916 - val_recall: 0.9875 - learning_rate: 1.0000e-04
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 754ms/step - accuracy: 0.9841 - loss: 0.0966 - precision: 0.9881 - recall: 0.9734 - val_accuracy: 0.9958 - val_loss: 0.0543 - val_precision: 0.9958 - val_recall: 0.9875 - learning_rate: 1.0000e-04
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 779ms/step - accuracy: 0.9926 - loss: 0.0846 - precision: 0.9951 - recall: 0.9854 - val_accuracy: 0.9958 - val_loss: 0.0488 - val_precision: 0.9958 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 781ms/step - accuracy: 0.9890 - loss: 0.0872 - precision: 0.9946 - recall: 0.9820 - val_accuracy: 0.9917 - val_loss: 0.0479 - val_precision: 0.9917 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 751ms/step - accuracy: 0.9929 - loss: 0.0800 - precision: 0.9948 - recall: 0.9848 - val_accuracy: 0.9917 - val_loss: 0.0551 - val_precision: 0.9917 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 768ms/step - accuracy: 0.9930 - loss: 0.0768 - precision: 0.9953 - recall: 0.9897 - val_accuracy: 0.9917 - val_loss: 0.0623 - val_precision: 0.9916 - val_recall: 0.9875 - learning_rate: 1.0000e-04
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 771ms/step - accuracy: 0.9886 - loss: 0.0844 - precision: 0.9911 - recall: 0.9846 - val_accuracy: 0.9958 - val_loss: 0.0444 - val_precision: 0.9958 - val_recall: 0.9958 - learning_rate: 1.0000e-04
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 771ms/step - accuracy: 0.9851 - loss: 0.0856 - precision: 0.9935 - recall: 0.9791 - val_accuracy: 0.9958 - val_loss: 0.0411 - val_precision: 0.9958 - val_recall: 0.9958 - learning_rate: 1.0000e-04
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 916ms/step - accuracy: 0.9905 - loss: 0.0798 - precision: 0.9949 - recall: 0.9841 - val_accuracy: 0.9917 - val_loss: 0.0503 - val_precision: 0.9917 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 793ms/step - accuracy: 0.9866 - loss: 0.0846 - precision: 0.9902 - recall: 0.9817 - val_accuracy: 0.9917 - val_loss: 0.0544 - val_precision: 0.9917 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 793ms/step - accuracy: 0.9883 - loss: 0.0827 - precision: 0.9903 - recall: 0.9783 - val_accuracy: 0.9958 - val_loss: 0.0488 - val_precision: 0.9958 - val_recall: 0.9958 - learning_rate: 1.0000e-04
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 740ms/step - accuracy: 0.9889 - loss: 0.0741 - precision: 0.9926 - recall: 0.9846 - val_accuracy: 0.9917 - val_loss: 0.0471 - val_precision: 0.9917 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9954 - loss: 0.0787 - precision: 0.9966 - recall: 0.9912
# Epoch 73: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 802ms/step - accuracy: 0.9953 - loss: 0.0785 - precision: 0.9965 - recall: 0.9910 - val_accuracy: 0.9917 - val_loss: 0.0534 - val_precision: 0.9917 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 748ms/step - accuracy: 0.9933 - loss: 0.0706 - precision: 0.9953 - recall: 0.9870 - val_accuracy: 0.9917 - val_loss: 0.0520 - val_precision: 0.9917 - val_recall: 0.9917 - learning_rate: 5.0000e-05
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 32s 796ms/step - accuracy: 0.9877 - loss: 0.0735 - precision: 0.9931 - recall: 0.9840 - val_accuracy: 0.9917 - val_loss: 0.0473 - val_precision: 0.9917 - val_recall: 0.9917 - learning_rate: 5.0000e-05
# Epoch 75: early stopping
# Restoring model weights from the end of the best epoch: 68.

# %% [markdown]
# ### define function to print text in RGB foreground and background colors

# %%
def print_in_color(txt_msg,fore_tupple,back_tupple,):
    rf,gf,bf=fore_tupple
    rb,gb,bb=back_tupple
    msg='{0}' + txt_msg
    mat='\33[38;2;' + str(rf) +';' + str(gf) + ';' + str(bf) + ';48;2;' + str(rb) + ';' +str(gb) + ';' + str(bb) +'m'
    print(msg .format(mat), flush=True)
    print('\33[0m', flush=True)
    return

# %% [markdown]
# ### define function to plot the training data

# %%
def tr_plot(tr_data, start_epoch):
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)
    index_loss=np.argmin(vloss)
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout
    plt.show()

# %% [markdown]
# ### define function to generate the confusion matrix and classification report

# %%
def print_info( test_gen, preds, print_code, save_dir, subject ):
    class_dict=test_gen.class_indices
    labels= test_gen.labels
    file_names= test_gen.filenames
    error_list=[]
    true_class=[]
    pred_class=[]
    prob_list=[]
    new_dict={}
    error_indices=[]
    y_pred=[]
    for key,value in class_dict.items():
        new_dict[value]=key

    classes=list(new_dict.values())
    dict_as_text=str(new_dict)
    dict_name= subject + '-' +str(len(classes)) +'.txt'
    dict_path=os.path.join(save_dir,dict_name)
    with open(dict_path, 'w') as x_file:
        x_file.write(dict_as_text)
    errors=0
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)
        true_index=labels[i]
        if pred_index != true_index:
            error_list.append(file_names[i])
            true_class.append(new_dict[true_index])
            pred_class.append(new_dict[pred_index])
            prob_list.append(p[pred_index])
            error_indices.append(true_index)
            errors=errors + 1
        y_pred.append(pred_index)
    if print_code !=0:
        if errors>0:
            if print_code>errors:
                r=errors
            else:
                r=print_code
            msg='{0:^28s}{1:^28s}{2:^28s}{3:^16s}'.format('Filename', 'Predicted Class' , 'True Class', 'Probability')
            print_in_color(msg, (0,255,0),(55,65,80))
            for i in range(r):
                split1=os.path.split(error_list[i])
                split2=os.path.split(split1[0])
                fname=split2[1] + '/' + split1[1]
                msg='{0:^28s}{1:^28s}{2:^28s}{3:4s}{4:^6.4f}'.format(fname, pred_class[i],true_class[i], ' ', prob_list[i])
                print_in_color(msg, (255,255,255), (55,65,60))
        else:
            msg='With accuracy of 100 % there are no errors to print'
            print_in_color(msg, (0,255,0),(55,65,80))
    if errors>0:
        plot_bar=[]
        plot_class=[]
        for  key, value in new_dict.items():
            count=error_indices.count(key)
            if count!=0:
                plot_bar.append(count)
                plot_class.append(value)
        fig=plt.figure()
        fig.set_figheight(len(plot_class)/3)
        fig.set_figwidth(10)
        plt.style.use('fivethirtyeight')
        for i in range(0, len(plot_class)):
            c=plot_class[i]
            x=plot_bar[i]
            plt.barh(c, x, )
            plt.title( ' Errors by Class on Test Set')
    y_true= np.array(labels)
    y_pred=np.array(y_pred)
    if len(classes)<= 30:

        cm = confusion_matrix(y_true, y_pred )
        length=len(classes)
        if length<8:
            fig_width=8
            fig_height=8
        else:
            fig_width= int(length * .5)
            fig_height= int(length * .5)
        plt.figure(figsize=(fig_width, fig_height))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
        plt.xticks(np.arange(length)+.5, classes, rotation= 90)
        plt.yticks(np.arange(length)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes)
    print("Classification Report:\n----------------------\n", clr)

# %% [markdown]
# ### evaluate model on the test set then save the model

# %%
tr_plot(history,0)
save_dir=r'./'
subject='Gym Exception'
acc=model.evaluate( test_gen, batch_size=test_batch_size, verbose=1, steps=test_steps, return_dict=False)[1]*100
msg=f'accuracy on the test set is {acc:5.2f} %'
print_in_color(msg, (0,255,0),(55,65,80))
save_id=str (model_name +  '-' + subject +'-'+ str(acc)[:str(acc).rfind('.')+3] + '.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 298ms/step - accuracy: 0.9979 - loss: 0.0368 - precision: 0.9979 - recall: 0.9979
# accuracy on the test set is 99.58 %

# %% [markdown]
# ### make predictions on test set and generate confusion matrix and classification report

# %%
print_code=0
save_dir=r'./'
subject='Gym Exception'
preds=model.predict(test_gen)
print_info( test_gen, preds, print_code, save_dir, subject )
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 195ms/step
# Classification Report:
# ----------------------
#                      precision    recall  f1-score   support
#
#        Bench Press       1.00      1.00      1.00        20
#            Dip Bar       0.95      1.00      0.98        20
#           Dumbells       1.00      1.00      1.00        20
# Elliptical Machine       1.00      1.00      1.00        20
#         KettleBell       1.00      1.00      1.00        20
#       Lat Pulldown       1.00      1.00      1.00        20
#  Leg Press Machine       1.00      1.00      1.00        20
#            PullBar       1.00      0.95      0.97        20
#     Recumbent Bike       1.00      1.00      1.00        20
#      Stair Climber       1.00      1.00      1.00        20
#         Swiss Ball       1.00      1.00      1.00        20
#          Treadmill       1.00      1.00      1.00        20
#
#           accuracy                           1.00       240
#          macro avg       1.00      1.00      1.00       240
#       weighted avg       1.00      1.00      1.00       240

# %%
def prepare_image(image_path):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    return img_array / 255.0

image_path = './dataset/tes/pullBar_92.jpg'
image_to_predict = prepare_image(image_path)

class_names = ['Bench Press', 'Dip Bar', 'Dumbells', 'Elliptical Machine', 'KettleBell', 'Lat Pulldown', 'Leg Press Machine', 'PullBar', 'Recumbent Bike', 'Stair Climber', 'Swiss Ball', 'Treadmill']

predictions = model.predict(image_to_predict)
predicted_class_index = np.argmax(predictions, axis=1)

if len(predicted_class_index) > 0:
    predicted_class_name = class_names[predicted_class_index[0]]
    print(f'Predicted class: {predicted_class_name}')
else:
    print("No predictions were made.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step
# Predicted class: PullBar

# %%
# !rm -r /content/tes/.ipynb_checkpoints

# %%
directory_path = './dataset/tes'
class_names = ['Bench Press', 'Dip Bar', 'Dumbells', 'Elliptical Machine', 'KettleBell', 'Lat Pulldown', 'Leg Press Machine', 'PullBar', 'Recumbent Bike', 'Stair Climber', 'Swiss Ball', 'Treadmill']
fig, axes = plt.subplots(nrows=10, ncols=5, figsize=(10, 19))
axes = axes.flatten()

for i, filename in enumerate(os.listdir(directory_path)):
    image_path = os.path.join(directory_path, filename)
    image = prepare_image(image_path)

    predictions = model.predict(image)
    predicted_class_index = np.argsort(predictions[0])[-2:][::-1]
    predicted_class_name = [class_names[idx] for idx in predicted_class_index]
    confidence = predictions[0][predicted_class_index] * 100

    img = tf.keras.preprocessing.image.load_img(image_path)
    axes[i].imshow(img)
    axes[i].axis('off')


    confidence_text = "\n".join([f"{predicted_class_name[j]}: {confidence[j]:.2f}%" for j in range(2)])
    axes[i].set_title(f"{predicted_class_name[0]}\nConfidence: {confidence[0]:.2f}%\n\n{confidence_text}", fontsize=8)

    if i == 49:
        break

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
model.save('./gym_model_densenet121_9958.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
imp_model = load_model('./gym_model_densenet121_9958.h5')

# Evaluasi model
results = imp_model.evaluate(valid_gen)
print("Validation Results:", results)

# Prediksi
predictions = imp_model.predict(test_gen)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.9958 - loss: 0.0411 - precision: 0.9958 - recall: 0.9958
# Validation Results: [0.041115425527095795, 0.9958333373069763, 0.9958333373069763, 0.9958333373069763]
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step

# %%
class_names = ['Bench Press', 'Dip Bar', 'Dumbells', 'Elliptical Machine', 'KettleBell', 'Lat Pulldown', 'Leg Press Machine', 'PullBar', 'Recumbent Bike', 'Stair Climber', 'Swiss Ball', 'Treadmill']

# Simpan ke file .pkl atau .json
import pickle
with open('/content/class_names.pkl', 'wb') as f:
    pickle.dump(class_names, f)

# %%
with open('/content/class_names.pkl', 'rb') as f:
    class_names = pickle.load(f)
print("Class Names:", class_names)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/Gym Exception-12.txt" "/content/drive/MyDrive/Colab Notebooks"
